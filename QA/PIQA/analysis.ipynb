# %%
import pandas as pd

# %%
data = pd.read_csv("result/mc_gpt_4.csv",index_col=0)
data.head(5)
# Out:
#                                      id  \
# 0  fe68f9ec-09fd-436e-bcaf-07863711ec2b
# 1  d73182e6-6916-48a0-b31f-2137e350776f
# 2  f8232939-914b-4a5a-af72-dc37cd042263
# 3  8748b18c-01df-4544-96ca-1defe1b182b7
# 4  f1386ea3-ee1e-4395-a760-747e37b11c30
#
#                                                 goal  \
# 0                                            dresser
# 1  To fight Ivan Drago in Rocky for sega master s...
# 2     How do you attach toilet paper to a glass jar?
# 3                       how do you put eyelashes on?
# 4                 Find spices easily in the kitchen.
#
#                                                 sol1  \
# 0                     replace drawer with bobby pin
# 1  Drago isn't in this game because it was releas...
# 2  Press a piece of double-sided tape to the glas...
# 3                         glue them on with mascara.
# 4  Arrange spices from hot to mild in the kitchen...
#
#                                                 sol2  label  \
# 0                 finish, woodgrain with  bobby pin       1
# 1  You have to defeat Apollo Creed and Clubber La...      1
# 2  Spread mayonnaise all over the jar with your p...      0
# 3  put eyelash glue on the fake eyelashes and the...      1
# 4  Arrange your spices alphabetically to make fin...      1
#
#                                        slot_question  \
# 0  dresser\nsol1:\nsol2:finish, woodgrain with  b...
# 1  To fight Ivan Drago in Rocky for sega master s...
# 2  How do you attach toilet paper to a glass jar?...
# 3  how do you put eyelashes on?\nsol1:\nsol2:put ...
# 4  Find spices easily in the kitchen.\nsol1:\nsol...
#
#                                          slot_answer  \
# 0                     replace drawer with bobby pin
# 1  Drago isn't in this game because it was releas...
# 2  Spread mayonnaise all over the jar with your p...
# 3                         glue them on with mascara.
# 4  Arrange spices from hot to mild in the kitchen...
#
#                                          pred_answer
# 0                           Clean and dust regularly
# 1          Train hard and learn his attack patterns.
# 2  Use a strong adhesive glue to stick the edges ...
# 3  Start by carefully removing the eyelashes from...
# 4        Label your spices for quick identification.

# %%
from rouge_score import rouge_scorer
scorer = rouge_scorer.RougeScorer(['rouge1','rouge2','rougeL'], use_stemmer=True)

# %%
f_score = 0
acc = 0
slot_ans_list = []
answer_list = []
for index,row in data.iterrows():
    answer = row['slot_answer']
    slot_answer = row['pred_answer']
    rouge_score_tmp = scorer.score(slot_answer,answer)
    f_score_tmp = rouge_score_tmp['rougeL'].fmeasure
    f_score += f_score_tmp
    print(answer,"|",slot_answer)
    slot_ans_list.append(slot_answer)
    answer_list.append(answer)
    if slot_answer.lower() == answer.lower():
        acc += 1
print("Acc: ",acc*1.0/data.shape[0])
print("Rouge-l F1: ",f_score*1.0/data.shape[0])
# Out:
# replace drawer with bobby pin  | Clean and dust regularly
# Drago isn't in this game because it was released before Rocky IV. | Train hard and learn his attack patterns.
# Spread mayonnaise all over the jar with your palms and then roll the jar in toilet paper. | Use a strong adhesive glue to stick the edges of the toilet paper on the glass jar.
# glue them on with mascara. | Start by carefully removing the eyelashes from their case, then trim them to fit your eye length.
# Arrange spices from hot to mild in the kitchen in order to find them by taste. | Label your spices for quick identification.
# Find a feather duster, and cut the feathers off every two inches. | Use a vacuum with a brush attachment.
# look up which console is the cheapest one in store. | Wait for a sales event such as Black Friday or Cyber Monday.
# Place a knife on the grill for around 15 minutes for the blade to be red hot. Gently push the knife through the meat to get a perfect cut. | Marinate the meat first, then cut it into even pieces or strips for even cooking.
# Get a solar clock for a reference and place it just outside a window that gets lots of sun. Use a system of call and response once a month, having one person stationed at the solar clock who yells out the correct time and have another person move to each of the indoor clocks to check if they are showing the right time. Adjust as necessary. | Sync them with an official timekeeper such as an online clock or a radio time signal.
# Boil the nuts in milk for about 20 minutes while stirring constantly. | Soak the nuts in a flavored brine
# pour a thin layer of oil into the cup holders. | Use a silicone cup holder liner for easy cleaning.
# wave a large blanket up and down to generate a gust of wind to cool the room down when it gets too hot. | Open the windows at night when the outside temperature is cooler.
# keep the temperature high and cook quickly. | Use a non-stick pan
# Spray dirty laundry with air freshener, and open a window to clear the room of smell. | Use vinegar in the washing machine as a natural odor remover.
# Use a blow dryer and gently remove melted gum. | Use a small amount of peanut butter or cooking oil and gently work it into the gum area.
# Just because liquid nails look dry in a short period of time it does not mean it is dried to maximum strength. | Liquid nails should dry for at least 24 hours before bearing any weight.
# Use a chainsaw to cut all the limbs off the tree. | Wear protective gear and inspect the tree for dead or damaged branches.
# plug them into your device. | Adjust the volume to your preferred listening level.
# invert the candle upside down and pull the wick until the lighter can reach it | Use a piece of uncooked spaghetti as a long match to reach the wick
# Air filters can be installed in any direction. | Follow the manufacturer's instructions.
# Gather dirt, wet it to make mud, and roll it into the shape of a ball, keep adding water so it will remain mud-like, add water whenever it begins to dry. | Collect the finer soil particles for the final coating and carefully apply them to the surface of the ball.
# Diffuse vegetable oil. | Practice mindful meditation
# soak the area in soy milk so that the region is colored by it. | Use alcohol-based hand sanitizer and gently blot the stain.
# move closer to the coals the longer it has been on. when almost finished, move directly on top of the coals. | Marinate the meat for at least a few hours before grilling for more flavor and tenderness
# chew on the toothpick | Gently glide it along the gumline to remove plaque.
# make it sugar and not salt | Provide it with a suitable habitat
# spray it all over your skin. | Pour a small amount of it in your coffee or tea.
# Get your crayons or paints together and give them to your fish to use. Let him or her color what they want.  Get that picture and tape to the backside of the fish tank. Make your fish wonderfully happy. | Sketch the layout and design of your desired picture, taking into account the size of the fish tank and the types of fish you have. Once your sketch is complete, finalize your picture with the appropriate colours.
# Put the Jenga set on the floor. | Start stacking the Jenga pieces in sets of three until the tower is as tall as you want it.
# Use a wooden box of required size and punch holes on the for allowing air passage. | Choose a box made of well-insulated materials like Polyisocyanurate (PIR) or Polystyrene foam boards.
# Use an old book and then print the book. | Fill the inside with sports statistics from the desired years.
# place them in an ink trey and they automatically transfer to their system. | Press your fingers on a digital scanner
# Use a soldering iron | Use double-sided tape
# mash up cooked white rice, and form a ball. wrap ground beef around it, and inject with olive oil. | Marinate it with spices and herbs overnight
# Leave in place without disrupting to prevent the milk from burning | Add a coagulant like lemon juice or vinegar
# drink some whiskey with coke. | Drink a sports drink with electrolytes
# Use a pen and paper and recreate the image by hand | Cut out the images and glue them onto the calendar slots.
# Drape fabric over your head. | Attach it to the main body of the cloak.
# Use a non-fat coffee cream powder instead of cream or milk in your coffee, to dilute the portion of coffee in the beverage. | Drink it black without any additives
# Add some peppermint oil to a spray bottle of water, spray self often avoiding eyes. | Drink plenty of water
# protect ice cream scoop from damage | Use it to wipe your mouth
# In the spring, snip off the dormant vines in pieces about 3 feet long. You need 4 buds for every piece that you cut. Leave the green or wet parts alone at the bottom of the plant. This will release new growth until the next winter, when you can cut them back again. Each cutting will produce a new plant that will germinate again. | In a large pot or in the ground, make a hole deep enough to fit the 3 buds. Put the cutting in the hole with the bud end facing upwards. Backfill the hole and water thoroughly. Place them in a sunny location and keep the soil moist until the cutting has rooted. This usually takes about six to eight weeks. After that, the new plant can be transplanted to its permanent location.
# ask it what's wrong with it. | Consult a mechanic
# Give them space, leave them alone to learn on their own. | Talk to them frequently using a variety of words and sentences.
# Place the kebab meat on the grill. | Marinate the meat and then put it on the grill
# is heavier than a paperweight  | Can be used to wrap leftovers
# Level the concrete using sweeps with float purchased from a local hardware store. | Use a finishing broom to create a non-slip surface on the patio.
# can hold together a  thick stack of paper  | Can secure a broken button on a shirt
# Do not use plain glue to get glitter to stay on ribbon, it will clump and make the ribbon too thick to use. | Apply a layer of glue on the ribbon, then sprinkle the glitter over the ribbon and let it dry.
# keep them on track. | Tell them an interesting story.
# Insert a spigot (a tap) into a maple tree, and turn the tap on. Water will come out of the tree that is full of sugar. Boil the sap down until it becomes thicker. It will form into a syrup that can be enjoyed on pancakes or many other dishes. | You can filter the syrup to remove any solid particles and then store it in clean jars. Keep it refrigerated or in a cool, dark place where it can last up to a year. Enjoy it later on anything from pancakes to desserts.
# leave it outside your front door. | Write "Return to Sender" on the package and drop it off at the post office.
# You can use any plant and make sure you place it directly in your kitchen windowsill. | Herbs like basil, thyme, and parsley are great options, as they can thrive indoors with adequate sunlight.
# can scoop books  | can stir soup
# To find a stud in the wall to secure workshop cabinets, the best thing to do is to measure inward from the corners of the wall, and drill every six inches until you encounter the stud.. | To find a stud in the wall to secure workshop cabinets, you can use a magnet to find the nails or screws that were used to mount the drywall to the stud.
# can replace a stove  | Can be used for a coin toss
# Use a toothpick. | Use a graphite pencil
# The best method would be to use a dinghy boat and paddle | Take a high-speed train if you're already in the UK
# building a fire safely | Eating meals with family
# Put the best show you have on free display but in the back of the circus. By time they get to that display they'll have spent a bundle | Promote it on social media
# slide the card on the machine. | Insert the card into the card reader with the chip facing up.
# After exercising or lifting weights extensively, apply a topical analgesic to the parts of the body you were training. Also apply an ice pack if needed to reduce swelling. | Ensure you stretch before and after your workout. It increases flexibility and decreases muscle tension, reducing your chances of experiencing muscle soreness post-exercise.
# Add baking soda  to the top of the meat and let it rest for five minutes. Remove the baking powder after five minutes. | Pound the meat to soften the fibers.
# sing to a group of people. | Play them a romantic song on a musical instrument
# Remove them from the oven and eat. | Let them cool on a wire rack
# Download an application on the phone that will help you learn French easily. | Use a language learning app or software.
# dry grass to remove all the water in it to prevent decomposition. | Bale the dried grass into hay bales.
# The best way to pierce your ears would be to insert a needle half inch thick into the spot you want pierced. | Use a sterilized needle if you're doing it at home.
# Wipe with tissue paper. | Wash with warm soapy water.
# place them in a glass until they melt into water. | Place them in a bag to create a cold compress.
# Put it out on a patio table. | Hang it in a well-ventilated area
# can form  on bleach bottle slowly. | can form on bread if left out for too long.
# use a power washer, with liquid wax | Apply it with a damp cloth
# cut growth hair | Cut through dense vegetation
# Remove anything harmful from your purse and just pick it up when they knock it over. | Teach your child to respect personal items and the importance of not touching certain things without permission.
# bring a small alarm clock to strong whenever your signal is strong enough. | Install a cell signal booster
# Take to the vet after a few months. | Start a vaccination schedule.
# put your finger over the number keys. | Lift the receiver and start dialing.
# let it cook in the oven for a bit  and pinch back together | Refrigerate it to firm it up before attempting to cut again
# See if there is any water missing from the bottle. | Check if the safety ring is detached from the cap.
# Place the cages in properly air-conditioned rooms, with water-fountains inside the cages for the rabbits to quench their thirsts. | Provide a small hideaway or shelter where the rabbit can retreat to for security and comfort.
# Hang christmas ornaments from the plant. | Add fairy lights for a magical touch
# Boil the leeks in water. | Chop the leeks before sautéing.
# One could reuse old kitchen jars as dog feeder for the pets. | One could use old kitchen jars for storing spices or dry goods.
# can stand on  foil  | Can be used to cover a dish
# One should make a jacket. | One could use a large plastic bag.
# dial the number and call. cancel the call, and it'll be saved in your call log. | Open the phone dialer, input the number, then select 'add to contacts'. Input the name and any additional details, then click 'save'.
# Drill the hole carefully. | Use a punch to create a guide hole.
# Go to your local pet shop or fish store and ask if they can refer you to a fisherman to source your fish and buy it from them. | Order them online from a reputable breeder or fish supplier.
# Soak paper in lemon juice and write on paper a Q-tip | Soak a toothpick in milk and write on paper with it
# wipe it off with a rag. | Dry it with a towel
# fry it in a pan. | Mix the dough ingredients together
# press the side button for one second and let go. | Press the power button located at the right hand side of the device.
# leave a cup of water inside the closet space. | Place silica gel packets in the closet
# put it in a safe. | Recycle it
# Carefully poke a hole through the back by using a Phillips head screwdriver and striking the end with a hammer. You can eyeball the location since it doesn't have to be exact. | Mark the spot you want to drill using a pencil. Then use a small drill bit to make a pilot hole before using the size you need.
# Store the glow sticks when not in use in a cool area. If possible, make sure the area is humid and moist, and away from direct light such as the sun. | Keep them in a cooler or any cold area when not in use; this slows the chemical reaction and prolongs the life of the glow stick.
# You can buy a tank as small as the Betta is. The fish will acclimate to its surroundings. It won't grow much in a small tank, but it will adjust. | A 5 gallon tank is ideal for keeping a Betta fish. It gives them enough space to swim around freely and also helps create a conducive environment for warming the water, which is important for this tropical fish.
# can be harder than the counter . | Can be positioned in the living room
# pour mix into a ladle and then dump the ladle out. | Use a ladle or scoop to pour it evenly.
# ensure that you hear a click when the door is closing after you. | Place a door stopper under the door.
# killing Wasp  | Shooting at a target
# shine a flashlight inside. | Use the oven window to look inside
# place a board under the coaster, and secure with zip ties and a glue gun. | Drill small holes and insert four small rubber pegs into the holes.
# Butter | Glue
# Cover it in house tarp | Cover it with a lid
# caramelize sugar in a pan and breathe in the steam from it. | Use a humidifier or take a hot shower
# put the cream inside a cup and then add hot water to it. | Chill the heavy cream before you start shaking it.
# Keep them in a pile in the corner of your room so you always have access to them. | Separate them into piles based on color and fabric type.
# Mix equal parts lemon juice and olive oil and  using a clean lint cloth, apply and rub in the direction of scratch until it not visible anymore. | Apply a coat of furniture polish after the dye has dried.
# add dry beans that have been ground with beet juice. | Add some cream or pureed vegetables.
# say you did it for them. | Accuse them directly.
# The use of any nail available to make the roofing job is advised. | Using a roofing nail at every crossing is the most effective.
# scrub it over the sink with a sponge. | Use a soft toothbrush to gently scrub it.
# drape a blanket over the devices to hide them. | Install safety locks on the cabinet doors
# can clean mold  | Can wash your hands
# can form penny easily | can be used to apply makeup remover
# coat the metal in an oil to protect it. | Cover it with a cloth or towel
# bake the eggs whole in their shells for six hours, and freeze. | Perform a floating test in water
# Use the handle of a hammer | Use a dough scraper
# To stop a pie crust from burning, cut the baking temperature in half and double the baking time. | Reduce the oven temperature and increase baking time.
# Drill the screw in at an angle. Drill a guide hole using a bit smaller than the screw at the same angle. | Use a screwdriver or power drill to drive the screw at the desired angle.
# place it in the microwave for one minute. | Place the tortilla in the oil for about 30 seconds each side until it becomes crispy.
# Put caramel on popcorn kernels then cook them on the stove top until they pop, once they are all popped you are ready to eat. | First, gather your popcorn and the ingredients for the caramel.
# turn on loud devices outside the room to muffle the volume from the room. | Install soundproofing insulation in the wall
# Put a white russian mix and ice in a blender and blend on high for 3 minutes until smooth. | Gather all necessary ingredients such as vodka, coffee liqueur, and cream.
# drink alot of caffeine. | Meditate or practice mindfulness
# beef, milk, cheese, bell pepper, curry powder and yellow mustard for seasoning. | ground cumin, chili powder, oregano, salt and pepper.
# push and shove as firmly as you can through the crowd. | Arrive early to secure a spot at the front.
# using your measuring cup on the countertop, open the lid of the oats and dump the container upside down over the oats, leveling the cup with your finger after you've poured the desired amount of oats into the cup. | Use a kitchen funnel over your measuring cup, and carefully pour the oats into the funnel.
# Start the band saw and put your wood on the top. Push it through the blade and let it drop to the floor. | Measure and mark the section of the wood you want to cut. Guide the wood slowly and carefully through the saw.
# throw it and crack it until the pumpkin seeds come out. | Draw a face or design on the pumpkin and carve it out.
# make sure you hear the click | Hold the lid firmly and twist
# take a small piece | Use a butterfly clutch
# mix them into your casseroles for extra flavoring in meals. | Use them as fertilizer for your plants.
# pat dry before frying | Dip in batter before frying
# Replace bathroom sink. | Avoid close physical contact with others.
# use a key to open | Sorry, but I can't assist with that.
# Drink green olive juice. | Apply a hot or cold pack.
# stand it up and then lean it against something. | Prop it up with a bike rack or kickstand
# put in a pot on the stove, turn the stove onto high heat, and keep the apple mixture there, bubbling, without stirring at all until there is less volume. | Peel and core apples, chop them into small pieces, add them to a pan along with sugar and spices, and stir until the apples are soft and the mixture thickens.
# mash it up before placing it in your mouth to swallow. | Grind it down with your molars until it's easy to digest.
# Roll out the dough so that is thin and put the dough in to a pot to boil. Add salt and oil to the water and stir until the pasta is done. | Knead the dough until it's smooth and elastic before letting it rest.
# Can be made from drawer alone | Can provide a detailed view of small objects
# make it the same. | Highlight it
# take off the bottle top and pour ketchup out. | Turn the bottle upside down and shake it until the ketchup comes out.
# Remove the seeds | Use more jalapenos
# Ask a worker at the grocery store if they can do a price check, if the barcode scans twice, its seedy. | Cut it open and check the inside
# add extra gravy and bread crumbs to the fried fish. | Use a splash of citrus or vinegar
# Wash your hands and make sure your nails are clean. Pat dry. Decide what color you would like them and start painting. Don't worry about getting color on the edges, Let dry. | Remove any old polish from your nails with a remover. Shape your nails with a nail file. Apply a base coat first, let it dry, and then apply the nail polish in your desired color. Let it dry fully before adding a top coat for extra shine and protection.
# call a credit card company. | Contact your bank or credit card issuer, as many offer free credit score information to their customers.
# Use dry cat food on spills. | Use an absorbent cloth or towel.
# make a small incision on the pregnant woman and then pull the baby out before putting it back. | Use a 3D or 4D ultrasound to see the baby's features in detail.
# can keep out rushing water from distant lands | can provide insulation and sound-proofing
# will decimate fish from the ocean into digestible pieces | Sells a variety of meats and sausages
# can fold a tablecloth  | Can hang on the wall
# Yes, you can try putting baby oil on your car and it will repel things from sticking to your car. | Yes, you can also use NanoWax All Surface Protectant. It creates a protective layer on your car, preventing dirt and grime from sticking to it.
# You can use a foam mattress and rip it apart and glue it to your wall. | You can use heavy curtains or carpets to absorb sound.
# Tie the Popsicle sticks together using string. | Paint the Popsicle sticks yellow and brown to represent the sunflower.
# Set up some spice jars on a driveway into a bowling triangle. use a golf ball to try to knock down all of the spices. | Mark off a designated bowling area and arrange the cans in a pyramid shape at the end of it.
# ignore them | Practice mindfulness and meditation
# add a bit of hot chocolate mix to a teaspoon of rice flour, and coat the chicken inside and out | Mix olive oil, garlic powder, rosemary, and thyme, and rub on the chicken.
# put the food inside of a small chest of water. | Store it in a root cellar or other cool, dark, and dry place.
# Put 4 sandboxes on the roof or deck or driveway if you have no ground floor. Plant veggies in them. | Create a rooftop garden by installing planter-boxes and adding soil and your preferred seeds.
# use a heat gun each day to dry the moisture from the dome. | Cover it with plastic wrap
# Wear a green hat. | Wear sunglasses.
# cut off the wrapping paper. | Carefully cut the tape with scissors.
# draw the clock | Use AM/PM to differentiate between morning and afternoon.
# cover building  | Use it as a filter
# ask a friendly looking stranger on the street to charge it. | Plug it into a portable power bank
# hold them in your hands. | Gather them up one by one.
# cut a hole in the cork on top. | Use a corkscrew to twist into the cork.
# hold down on it. | Swipe down on the home screen and type in what you need in the search bar.
# add a few | Use essential oils
# boil it in a frying pan. | Add vegetables and seasonings for flavor.
# erases  pencil marks | Use a pen
# place them on the table. | Use a high chair.
# Breathe into your hands. | Drink a glass of water.
# place a wall mirror on the floor of the cabinet | Use a flashlight to illuminate the area under the garbage disposal machine
# go to the theme park on a popular holiday instead. | Go early in the morning when the park just opens
# can  ladle a chicken breast | can scoop ice cream
# how to sanitize a sponge | Mix vinegar and water solution, heat it in the microwave, then wipe the inside with a clean cloth.
# spray it on your face and let it sit. | Dab a small amount directly on the spot and gently blend with your finger.
# is used to burn up a razor  | is better at breaking ice than a spoon
# grate the wax and melt, in a double boiler. Add the oils to the water in the bottom of the double boiler. | Pour the scents into the lotion bars mixture before letting it solidify.
# use it. | Conduct a trial run
# look for any mouse you see and then put them back outside afterwards. | Seal off any potential entry points in the home
# cut with only small, firm motions so that the knife doesn't move quickly. | Use a bracing hand to keep the stick stable
# dig a hole under the shack, and start a fire in it before covering it back up. | Install a system of pipes under the floor to circulate hot water.
# You can purchase a window squeegie with foam along one side and a rubber strip along the opposite side. Dip the window into hot soapy water and then vigorously wipe down the squeegie with a soft lint-free rag. Observe the results and pick any lint off the window that remains. | Use a homemade cleaning solution of vinegar and water. Spray the solution on the windows then scrub with a brush. Wipe off the solution with newspaper or a microfiber cloth for a streak-free finish.
# lay down. | Display your skills or achievements.
# move it up and down | Nod it up and down
# break it apart into two pieces. | Position the sandwich on a cutting board and slice through the middle with a sharp knife.
# make them think that their room will catch on fire otherwise. | Start a game of find the hidden treasure.
# Wipe down with index cards. | Use a damp cloth to clean it.
# soak the wood in Vodka or Ethanol. | Stain it with a dark wood stain
# cover  pillows  | Wipe off sweat
# Practice being hit in the head to develop a tolerance to being hit. | Improve your head movement and footwork to dodge punches.
# take a shower to soothe the growling. | Drink plenty of water
# Look for a dumpster with a lot of traffic and jump into it. Get a box from the dumpster and load the items you want into it. Be sure to do this in day light so you will be safe and seen. | Take precautions such as wearing gloves and a long-sleeved shirt to protect yourself, then properly clean and disinfect any items you decide to keep.
# If you hum a tune while you garden, humming birds will want to sing along with you so you don't have to really bother with feeders or special flowers. | Plant flowers that are bright and rich in nectar, as these are particularly attractive to hummingbirds.
# Use super glue | Use lemon juice
# delete it all and look for properly titled files. | Label each song manually.
# research ahead of time to create a strict itinerary of plans and stick to it diligently so that there is no free time leftover. | immerse yourself in the local culture, try new foods and experiences.
# tip the bottle upside down and let the contents splash into the mixing bowl. | Add it directly to your recipe mixture
# arrange with other coworkers to be sure that everyone drives their own vehicles. | Use public transportation instead of a personal vehicle.
# tell a lie about something | Admit your mistakes or wrongdoings
# You can use sticks and glue them to the bird house wherever you see fit. | You can use twine and sticks to create a natural looking barrier.
# freeze the bacon in strips, and bake in the oven until tender. pour water over the bacon, and collect the grease. | Let the grease cool, then pour it into a jar for storage.
# add extra water to the pot at the end. | Add more spices or herbs
# leave it alone. | Focus entirely on the task at hand
# offer up free tutorials in an area of your expertise. | Offer a lawn mowing service for your neighborhood.
# Get all the tools and measure bed. | Start constructing the bed bench according to the design plans.
# Make bread the old fashioned way and simply mix in frozen corn before putting it in the oven. Then bake for the normal amount of time. | Gather all necessary ingredients including cornmeal, flour, sugar, baking powder, salt, milk, eggs, and butter. Mix them together and bake in a preheated oven.
# Fill the cracks with dirt in order to smooth down all the cracks. | Apply a concrete sealant to prevent further damage
# Take a pain killer. | Drink plenty of water and eat nutrient-rich food.
# grips house  | Holds ball
# Use the string from a beading kit, and tie your nuts and bolts into bundles. | Use a toolbox with various compartments to sort and store them.
# umbrella, bricks, concrete walkway, acrylic paint, textile medium and a paintbrush. | Paintbrushes, a palette, a bowl of water, and a rag.
# feel your stomach | Visit a doctor for a check-up
# A quick way to apply the nail polish is to use a fairly big brush, and then use flesh-colored nail polish to cover up any places that turned out messy. | Start by applying a base coat to provide a surface that the nail polish can stick to, allowing it to last longer. Once dried, apply the polish starting from the cuticle to the tip, using slow and steady strokes. Apply the nail polish in three strokes. Start by dipping the brush into the bottle and getting a decent-sized bead of polish at the end of your brush. Then start in the middle, then one on each side. Make sure to cap the free edge to prevent chipping. Allow the polish to dry fully, then add a top coat to create a shiny finish and further prevent chipping.
# Pour some sulfuric acid down the toilet. | Use a toilet brush to scrub the bowl.
# Use peanut butter. | Use hummus.
# Go to the library and find a very popular children's book, if you don't know which are which, ask the librarian to help you to get the one that the majority of kids in the target age group tend to check out of the library.     Now check it out and take it home and try to copy it but change a word here and there so that you won't be sued for plagiarism .. find an . illustrator, self publish | Decide on the story theme and characters, develop a storyline and plot, write a draft, edit and revise it multiple times, and start creating illustrations to complement the story.
# to sew and mend mittens  | To mark locations on a map
# can hide a plastic bag  | can be used to place furniture on
# leave it running for awhile to build up it's power. | Clean or replace the filter regularly
# pierce the top of the egg with a butter knife and then pull the off. | Use the edge of a bowl to lightly tap the egg until it cracks.
# add sugar and wine into the rice to help make more steam for the broccoli. | Steam the broccoli and mix it in after the rice has cooked.
# fold the stems in half. | Place them in water immediately.
# Use the counter top, it is works just as well as an ironing board and doesn't cost anything to have. | Use a flat, heat-resistant surface, preferably with a protective layer such as a towel.
# One should use an actor. | One could use a digital picture frame.
# Put your fragrance and essential oils in fat soluble materials that won't dissolve in water so you can have the scent last a while. | Mix your dry ingredients together in a bowl
# hold your eyes open tightly. | Apply a cold compress
# Using a sharp paring knife chop the jalapeno into small bits, and use your finger tips to pick the seeds out. | Use a spoon to gently scrape out the seed pack from the inside.
# soak the pieces in water and then bake them. | Apply a layer of wood filler before sanding.
# Wipe the stain with a rag and dish soap. | Apply stain remover and wash immediately.
# cut the shapes out of a folded piece of paper and leave loosely arranged in the card. | Decorate the front of the card and write a special message inside.
# Search near a body of water for washed-up planks. | Scout for construction site waste or scraps.
# Use a 1 gallon milk jug filled with batter operated fairy lights to create a stylish and simple camping lantern. | Start by filling the jug with water to stabilize it and amplify the light.
# Use recipes that they don't need. | Conduct research and experiments
# Put a lot of cardboard boxes in there and throw cans and boxes of pantry goods in those so nothing rolls on the floor when you open up the door to the pantry | Label all items and containers for easy identification; arrange items according to their usage frequency.
# Find a tin can or bowl the size of the circle you'd like to draw. lay the object youve chosen in the center of the place you want your circle. Using a pencil, trace around the object until the lead marking meet. | Using a round object as a guide, trace around it with a pencil to create a perfect circle.
# jump over it. | Stumble against it.
# cleans clothes  | Wipes the floor
# spray with WD-40, before putting in your backpack. | Use a small pouch or case specifically designed for earbuds.
# can watch video footage. | Can be used for speaking in a presentation
# can support soup  | can hold books
# Press down hard on the chicken with a spatula until it looks fried | Regularly baste the chicken with the pan drippings
# cooks carrots  | Rotates meat over a fire
# puree a few olives with a splash of vodka, add to the martini. | Use caper brine or pepperoncini brine.
# cut the olives in half with a paring knife, removing the pit from one of the sides where it remains using your fingertips. | Use an olive pitter or cherry pitter to easily remove the pit.
# Just start painting right out of the can. | You need to apply a primer before painting.
# From the power supply, regulate the amount of current and voltage supplied to the fan. | Use the fan's speed control settings.
# Use magnets on either side of the table to hold down the paper. | Place a paperweight on top of the paper.
# can power  stove  | Can be used to pound materials
# Give him a box filled with plastic utensils and tumblers and measuring cups. | Sew buttons onto a soft cloth, creating a textured playmat.
# put seasoning all over it. | Place your meat in a resealable bag, add your chosen marinade, seal the bag, and ensure the meat is sufficiently coated.
# put water over it. | Apply a moisturizing cream regularly
# Once the plastic has cooled sufficiently wrap a heavy duty rubber band around the mold for at least 5 mins. | Allow it to cool completely before removing from the mold
# Drive to your local KFC or Church's chicken and buy a tub of your favorite Fried Chicken. | Marinate the chicken in your choice of spices before coating it, to enhance the taste
# chew on it with your gums | Put it in your mouth and use your cheeks to create a vacuum
# You really don' t need to remove it, eventually it will fall off itself that way you don't have to worry about the head being left behind.  After it falls off, then cleanse area where it fell from and flush the tick down the toilet. | Use a pair of tweezers to grasp the tick as close to the skin's surface as possible. Make sure you're pulling upward with steady, even pressure and avoiding twisting or jerking so as to not leave parts of the tick in the skin.
# place items in it until you want to close it. | Start by opening it and adding items one by one.
# seals soil  | forms building foundations
# Build a special room with no windows and no tech type of lights, indicator lights etc. Take a nice shower, take magnesium glycinate 2x a day and sleep like a baby! | Meditate or do relaxation exercises before bed.
# give it a time limit. | End its process
# Buy a pack of rubber feet and just set them on without glue. | Drill a small hole and secure it with screws.
# glue the edges of the run together with fabric glue. | Use them as a hair tie or headband.
# eat only two meals in the 24 hours prior. | Review the procedure with your doctor
# place them outside in the sun for several days | Store them in an airtight container
# First find the radius of your pie dish. Double it. Then take that number and multiply by pi (3.14). This gives you the circumference you need. | Cut off the excess dough and crimp the edges.
# can start fires with a whisk  | is filled with a beverage
# Do bicep and tricep exercises until you cannot do any more from exhaustion. This will ensure the most growth. | Lift weights regularly, increasing weight as strength improves.
# can store tin foil inside | Use a pencil eraser as a temporary back
# Make sure you spray them with glue. | Use the appropriate wrench for tightening
# Use a metal file. | Use an angle grinder.
# keeps the sun warm | Provide comfort and warmth to humans
# use hot water and furniture renewing oil. | Use a microfiber cloth and vinegar.
# Buy kraft and cook it to the instructions then serve. | Bake it in the oven with a layer of breadcrumbs on top for a crispy finish.
# You should hang them behind you, so that when your voice projects and bounces off the wall in front of you it will make it quiet. | You should hang the sound dampeners at ear level when seated for the best sound absorption.
# sits cardboard box  | sits room
# yes, as long as the varieties are not mixed, or mixed with water. | Yes, but you need to consider the oil's smoke point and flavor
# an empty milk jug. | empty glass jars.
# open the heater cover and pry a screw driver into the wheel. | Disconnect it from the power source and then reconnect it
# can be forced into a  crowbar  | can be used for watching movies and shows
# string wire  | Flatten dough evenly
# is stronger than a paperweight . | Can be used for grilling
# Shyness is a common cause of awkward pauses in communications in certain social settings, or meeting people, but if the tongue is actually tied it may need surgical removal. | They may encounter unfamiliar or stressful situations that cause them to become nervous and struggle with expressing themselves verbally.
# let them soak in cold water for five minutes | Use baking soda and vinegar to scrub them.
# melt the chocolate chips by adding it directly to a pan | Place the chocolate in a microwave-safe bowl and heat it in 30-second intervals, stirring after each, until it's fully melted
# dress like you do not care about your surroundings. | wear clothes you feel confident in
# place the false lashes on top of your real lashes. | Cleanse your eyelashes with non-oil based makeup remover to ensure they are clear from any dirt or oil.
# The best underwear to wear would be a standard bra, as it is really important to cover the upper body, considering the dress is strapless. | Adhesive bras are also an optimal choice for strapless dresses, providing support and invisibility under the dress.
# Buy a car with a carseat already installed! | Secure the base properly to ensure safety.
# pour a small amount of nail polish remover in a dish, and soak your skin for two hours. | Use soap and warm water to gently scrub it off
# can smash a leaf open | can chop firewood
# Soak rice in water and and microwave. | Cover it with a damp paper towel and microwave.
# writes on the ground  | Creates messages in the sky
# check its color. | Weigh it on a scale.
# Play catch with them in the backyard. | Use them as doorstops.
# Be sure not to smoke or eat anything that could cause the teeth to get dirty. | Use a whitening toothpaste.
# A handsaw | A Table Saw
# place one box next to another. | Start with the largest box on the bottom
# you should mentally picture the assembled furniture and put every piece together the way you pictured it. | You can also gather all the necessary tools like screwdrivers or hammers, identify each part and their respective locations, and start building based on the given instructions.
# swallow a cup of water mixed with salt and vinegar and soap. | Gargle with warm salt water.
# Take two sticks of wood of desired thickness. cut them into equal length, while chopping away a diagonal piece from one end of both pieces at an angle of 45 degrees. Tie both the piece using a strong string. | Use a chisel or carving knife to carefully shape the clamp, ensuring the grip is strong and effective.
# place in the microwave on high, and add water to the chopped wax. | Place the beeswax in a heatproof container
# Slowly turn the handle counter clock wise while using sand paper. | Use a lathe to evenly shape and smoothen the handle.
# replace the meat with other protein substitutes like beans. | Increase the amount of physical activity or exercise you do daily.
# add sour cream and a bit of honey. | Add a pinch of baking soda
# can hide a bin bin  | can be painted with nail polish
# jump up off the ground. | Bend your knees slightly and use your leg muscles to push off the ground.
# You can use oils and add as many drops as you'd like. | You can use essential oils of your preferred fragrance.
# Put ice in the pitcher not in the individual glasses. | Use frozen lemonade cubes instead of ice
# Using a hammer, press the hammer down on the pallet to get the nails out. | Using a crowbar or pry bar, carefully leverage to wedge apart the pieces of the pallet.
# can beat up stalks of wheat from the fields to make a cake | Can stir soup, stews, and sauces while cooking
# use a remote controlled controller to the computer like an application to control the computer from another location | Use a remote desktop software like TeamViewer or Chrome Remote Desktop
# look out at your car often and inspect for anything suspicious. | Install an alarm system that will alert you when there's a break-in.
# Wait for the phone to prompt you about the update and then do it. | Connect it to Wi-Fi for a stable connection.
# One should set up a cable box. | One should tune into a public broadcasting station.
# use lye soap with a little lemon juice mixed in and rub for two hours. | Wash your hands with lemon juice
# put little bit of butter in pan | Toast it until golden brown on both sides
# wash socks  | Hold papers together
# put the weed inside and heat up the entire bottle. | Cut the top off the soda bottle
# open the app, and click add a post and type where you are and click post. | Open the Facebook app, go to the 'Status' box and then select 'Check In' to share your location.
# let it go down the sink drain with water running. | Pour water over it until it goes down the drain
# keep your eyes closed for better focus and then try to relax and sleep. | practice deep breathing and observe your surroundings carefully.
# can wipe dish towel  | Cover yourself with it
# using a spatula, scrape the egg up from the sides towards the middle of the pan, and flip the raw egg over like a pancake while the eggs are cooking in the frying pan. | Whisk the eggs in a bowl before pouring them into the pan, this will add air to the eggs making them fluffy.
# can cut glass  | can cut through bread
# Use a paintbrush dipped in bleach and mustard. | Use a toothbrush and baking soda
# Once you have completed the dome earrings roll them into a ball using your hands. Then cover with glue. | Cut a circular piece of paper, then fold it into half twice, then push it out in the center to make it dome-shaped.
# Memorize the intact keyboard. | Label each cap as you remove it.
# go slow. | Increase your pace.
# sit forward. | Lean back on a chair.
# has a blade  | Is used to clean the floor
# Hold the mic close to your lips ensure you are touching them. | Speak in a clear and steady voice.
# tell them what to do. | Train them properly
# Lemonade can be made using vinegar and sugar, if you run out of lemons. With enough sugar you can't really taste the difference. It might need some yellow food colouring to make it look "lemony", which is quite important because the visual impact of food can rival the impact of the taste of the food itself. | Add in some freshly picked mint for an extra fresh taste. After you've added the lemon juice and sweetener, give your lemonade an aromatic twist by crushing some mint leaves and throwing them into the pitcher. Stir it well and let it chill in the refrigerator for an hour or so before serving. This will allow the mint flavor to infuse your lemonade, giving it a refreshing edge.
# give them the money in their hand. | Hand it directly to the bartender.
# Hang earrings on pizza cutter. | Hang earrings on a corkboard.
# Cover rolled oats with water in a cereal bowl. Cook for 2 minutes. Add milk or cream and stir in some brown sugar to taste. | Open a packet of oatmeal, mix with boiling water and stir. Let it cool, add fruits and nuts for added flavor.
# Invite 10 or 12 kids over half an hour before the party starts. With them watching, blow up a couple of balloons but tell the kids  they aren't allowed to touch them. Then, leave a box of pins on the table and say "and don't touch these either" very clearly. Leave the room until you hear the popping sounds.  When you come back in, tell them if they want balloons at the party they're the ones who have to blow them up. You'll have a roomful in about 10 minutes flat. | Use a balloon pump or air compressor to save time and breath. This can also insure that all balloons are of consistent size. Be careful not to overfill as this may cause the balloons to pop.
# poke each wall of the building. | Explore different rooms.
# is more useful than a shovel . | can ruin food.
# Sew your own clothes. Print out labels from clothes that you like and sew them on. Great way to save money. | Shop during sales or discount seasons at department stores.
# Plant daffodils, foxglove, poppies, thyme and lavender | Set up a water source like a small pond or birdbath.
# Cut up the watermelon and squish it to make a juice and then add alcohol. | Purchase a ripe watermelon from the store
# Take the end with the ball and swing the rope around so that it is lighter and hence easier to swing. | Grab the ball and pull it back, then let it go to start the swinging motion.
# Store the pancakes flat in airtight plastic bags and microwave them at 30 seconds increment to warm up during the week. | Store them in an airtight container in the refrigerator.
# quench rice cooker  | Flush waste
# freeze for two hours, and then take kitchen shears to cut into strips. Then use a sharp knife and mince, rubbing with a little salt as you  go. | Use a very sharp knife to ensure clean cuts without tearing the meat.
# Use a leaf blower, point it towards each blade individually, and turn it on to spray the dust around the room. | Use a long-handled duster, reaching up to swipe each blade from base to tip.
# Cut the grapefruit in half and then in chunks . put it into the blender and blend until drinkable and then drink it. | Cut the grapefruit in half, use a grapefruit spoon to scoop out each section and eat it.
# You should first start with the bigger pieces and then the small ones. | You should read the instruction manual carefully.
# Frosting | Olive oil
# hold the two ends together. | Snap any additional buckles or closures to secure the contents inside.
# leave a baby monitor in the bathroom. | Install a lock that can be unlocked from both sides
# low and slow for at least six hours. | Marinate it beforehand for extra flavor
# dip the toast into a tub of butter. | Melt the butter and brush it over the toast.
# Put up a no ducks allowed sign on the beach. | Install a fence around the beach
# soak it in hot water for a bit. | Soak it in a solution of bleach and water
# let it sit on the ground. | Nail it to a wall
# stop flooding  | hydrate your body
# You need to insert a screwdriver in an electrical socket while your second hands touches two metal pins on the motherboard. | Pressing the power button on the desktop tower.
# argue nonstop. | Prepare thoroughly
# Cover the planters with a base layer, and then spray with clear spray paint, and then splatter with the insides of a few glow sticks. | Collect a variety of plants, preferably those that don't require much sunlight. After the paint dries, plant your greenery in the planter.
# do it quickly | double-check your work
# The dog is trying to get away from their owner, the handicapped owner is likely abusing the creature and you need to help the animal. | You can also call 911 or local authorities to inform them about the situation, providing the exact location and details about the service dog.
# To reshape a steel buckle, you have to pull it apart to desired shape. | Cool it down quickly to retain its new shape
# let it run free outside. | Take it to a park or open space where it can safely run and play while you still hold onto the leash.
# throw it away from you. | Take it to a recycling or disposal center
# Place bed sheet on soil. | Install a frost protection cover.
# Use your hands and rub the butter into the flour until the butter is completely melted. | Use high-quality ingredients for the best results
# can pierce needle easily | Use it to pick a lock
# let the air out. | Use a pump
# Fold over the outer edge of dough and insert cheese. | Seal the edges securely to prevent cheese leakage.
# Water dissolves iron by causing it to rust, therefore slowly the iron will be dissolved | Nitric acid can dissolve iron effectively
# watch it on your tv. | Use a streaming service like Netflix or Hulu
# break the top of the bottle with a hammer to access the wine. | Use a key or a knife to wiggle the cork out.
# scrub it. | Use a descaling solution
# burns air  | cuts through metal
# use white flour and water. | Use a correction tape.
# turn it on. | Stay focused and determined.
# heat the over up higher for the remaining time | Lower the oven temperature
# poke it with the knife every 2-3 minutes, until it stops bleeding. | Check the firmness of the steak.
# holds  foot  | Strains liquid from cheese
# burn it a little. | Place it in the oven at high heat
# can be used to insulate against boiling water into | can be used to carry water
# run under cold water after heating | Place it on a heat-resistant surface to cool down naturally
# Wrap the entire bowl in plastic wrap, and then turn on high to contain splatters. | Start the mixer on a slow speed
# Rising prices can signal a deflation, but do not necessarily cause a correction in recession. The worst case scenario of all would be rising prices and unemployment concurrently. Rising cost of living relates to rising costs of production and services. | Rising prices may not correct a recession but could potentially exacerbate it, especially if wages do not keep pace with inflation. This could result in decreased purchasing power and a slowdown in economic activity. Effective strategies to correct a recession often involve measures such as fiscal stimulus, monetary policy adjustments, and efforts to improve consumer and business confidence.
# shove them down the shower drain. | Put them in a sharps container
# Use acrylic as it is way cheaper than glass and still has a lot of pass-through for light to get in. | Use a small heat lamp for maintaining the ideal temperature.
# can make a sofa invisible | Can keep you warm at night
# can cut camera easily | Can be used to water the garden
# sweep what you can, and then use a nail file to crush it further. | Use a vacuum cleaner to safely suck up the small pieces.
# use a wooden sheet to make way for easy way of loading the containers to the truck | Use a forklift to lift the containers into the truck.
# can clean hair  | Can be used as a tissue paper
# eat more. | Take deep breaths
# search your name in the search bar on the top. | Click on your profile picture in the top right corner.
# Just get on the bike and start riding to learn how to do it consistently. | Start by learning to balance on the bike without pedaling.
# can enclose a hula hoop  | can hold fruits
# Flush after each use. | Install a dual flush system
# look up reviews for the movie to better understand it. | Watch it alone in the dark
# Use a spanner and revolve the spanner over the bolt until the bolt is opened. | Use a socket wrench by fitting it over the bolt and turning it counterclockwise.
# take the item back to the original store, and switch it for something else you want to keep. | Contact the online store's customer service for a replacement or refund.
# Brew some kool-aid. | Drink a glass of water.
# can be used like a  marker  | Can secure a piece of wood
# dial fuzz under contacts. | Call the police
# Brush oils after soap had been molded. | Mix in essential oils of your choice.
# pack the basket with bulk dry good like beans and rice. | include affordable yet nutritious items like canned vegetables and fruits
# Empty one of the bedrooms and put an ad on Craigslist to have someone come and rent a room from you thus bringing your mortgage payment down. | Set up an automatic transfer from your bank account
# put the tobacco leaves inside of the can along with a match and then cover the can's hole with your mouth and inhale the smoke. | Light the tobacco and inhale through the mouth opening.
# You can keep your latex gloves in the glove box to keep them safe from theft and damage while you are away from the car. | You can keep a flashlight, tire pressure gauge, and a portable phone charger for emergencies.
# say it. | Avoid the topic
# press flash. | Press the flash button on the side.
# implements playback.  | Amplifies voice
# cut diagonally | Use a pencil sharpener
# You can get tiny letter stickers that just stick on the computer keys, and you may never have to bother again with windex or vinegar. The F keys are usually tricky, as they are so small, however you can place or tape a cardboard sign above these ones, that indicates what each one should be. | Use a can of compressed air to blow out dust and debris that may be stuck between the keys. Fire short bursts of air under the keys, ensuring you cover all areas of the keyboard. Be careful not to damage the keys with the force of the air. After blowing out the debris, you can use a damp cloth with a little dish soap to gently clean the surface of the keys. Avoid using too much water, as this can damage the electrical components.
# can stab leopard  | can measure angles
# lay under a light cover only, keep yourself between them and the other parent and put pillows on the ground by the bed in case the baby falls off. | Ensure the bedding is light and minimal to prevent overheating or suffocation
# Dip the chicken in hot sauce and then fry. | Dip the chicken in egg before breading it.
# Use a metal file | Use a chisel
# When a plane wooden panel in half, it is best to first make sure it is smooth and there are no branches in the wood. | Use a circular saw for a precise cut
# Minimalist wallets are used to only carry currency notes so that there isn't the added weight of coins. | Minimalist wallets are for reducing pocket bulk and carrying only the essentials.
# Go to the library and check out a book of poetry and see what you like to read and write. Sit down and copy the poem from the book and claim it as your own. Instant poet. | Join a writing group or workshop for feedback and inspiration. Experiment with different forms and styles of poetry.
# any way you want, until it is brown. | You can roast it in the oven
# Soak the meat in plain tap water for a few minutes. | Steam the meat in a high-humidity environment.
# leave pillows next to where your car parks in the garage. | Install rubberized corner and wall guards.
# use a nail file on their teeth. | Use a special canine tooth file.
# simply boil the pastry in order to bring more shape and crisp to it. | Put it under a broiler, but keep a close eye so it doesn't burn.
# Go to a park or near by forest where pine trees are growing. Snip off a the tips of a few pine needles, especially if there are new shoots. Although you may love Rosemary's cooking, do not be afraid to replace Rosemary if she is no longer available. | Use thyme or sage
# wash them in the sink with soap. | Use a lens cleaning solution and microfiber cloth
# Dig Underwater  | Dig Soil
# shut off your devices. | Turn off the wifi directly from your device settings.
# Jump up and down on it, it should eventually break. | Use a hammer and chisel to chip at it
# Starting at one end use a knife to peel a cucumber in a circular/clockwise direction to produce one long ribbon. | Wrap the cucumber ribbons around the salmon rolls.
# give them space to get over it. | Send them photos or reminders of home.
# Make sure the can is wet by soaking it in water. | Wear protective gear such as gloves and safety glasses.
# can hold milk  | can display a vase
# removing peroxide safely | Removing nail polish
# As long as it cover you chest. | You need one large enough to fit over your body
# Dry wet clothes in dryer. | Use a humidifier
# can mark up a thin sheet of paper with graffiti.  | Cover an object for a new, colorful look.
# cut off the white that is around the yolk and eat the yolk. | Peel it off before eating.
# dip it onto asphalt for 2 seconds and it should ignite. | Strike it against the side of the matchbox.
# cut out a piece of metal in the same shape of your key. | Take the key to a local locksmith and have them create a duplicate.
# Peel the oranges and use a hand mixer. | Strain the pulp to remove any seeds and excess skin.
# can clean a dirty white t shirt clear of grime | can remove dirt from a driveway
# Acc:  0.0
# Rouge-l F1:  0.17137418842939134

# %%
# data['slot_answer'] = slot_ans_list
# data['answer'] = answer_list
# data.to_csv("result/mc_gpt_4.csv")
